# %% [markdown]
# <a href="https://colab.research.google.com/github/franmarq/ml-notes/blob/main/10_Create_a_Batch_Inferencing_Service.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.30.0 to work with aml-workspace

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8903333333333333
# AUC: 0.8783297676501318
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# blob_data - Default = False
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 41 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 42 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "compu2"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
#   - azureml-core
#   - azureml-dataprep[fuse]
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData
from azureml.core.runconfig import DockerConfiguration

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [77a68c4a][852ed78e-8c36-4a28-9a52-f715117f1124], (This step will run and generate new outputs)
# Submitted PipelineRun 39179b6d-e8c9-49b3-be5e-6c7afb2ed872
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/39179b6d-e8c9-49b3-be5e-6c7afb2ed872?wsid=/subscriptions/7bcf0e2e-9911-4b19-a0db-99354664b6f1/resourcegroups/aml-resources/workspaces/aml-workspace&tid=935b4e79-1fd0-49cd-ae65-f81a2054edd6
# PipelineRunId: 39179b6d-e8c9-49b3-be5e-6c7afb2ed872
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/39179b6d-e8c9-49b3-be5e-6c7afb2ed872?wsid=/subscriptions/7bcf0e2e-9911-4b19-a0db-99354664b6f1/resourcegroups/aml-resources/workspaces/aml-workspace&tid=935b4e79-1fd0-49cd-ae65-f81a2054edd6
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 4fd847a9-e79f-48a2-b79a-a87813473cfc
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4fd847a9-e79f-48a2-b79a-a87813473cfc?wsid=/subscriptions/7bcf0e2e-9911-4b19-a0db-99354664b6f1/resourcegroups/aml-resources/workspaces/aml-workspace&tid=935b4e79-1fd0-49cd-ae65-f81a2054edd6
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/06/20 14:04:00 Downloading source code...
# 2021/06/20 14:04:01 Finished downloading source code
# 2021/06/20 14:04:02 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/06/20 14:04:02 Successfully set up Docker network: acb_default_network
# 2021/06/20 14:04:02 Setting up Docker configuration...
# 2021/06/20 14:04:03 Successfully set up Docker configuration
# 2021/06/20 14:04:03 Logging in to registry: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io
# 2021/06/20 14:04:04 Successfully logged into a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io
# 2021/06/20 14:04:04 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/20 14:04:04 Scanning for dependencies...
# 2021/06/20 14:04:05 Successfully scanned dependencies
# 2021/06/20 14:04:05 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1@sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1@sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 01bf7da0a88c: Pulling fs layer
# f3b4a5f15c7a: Pulling fs layer
# 57ffbe87baa1: Pulling fs layer
# 86120caa19f5: Pulling fs layer
# c0f2d44469de: Pulling fs layer
# 638bc09d59ce: Pulling fs layer
# cec7eddb8044: Pulling fs layer
# 31cda9815495: Pulling fs layer
# a1b48f84f0d1: Pulling fs layer
# 484f821166bc: Pulling fs layer
# 6d70e314b196: Pulling fs layer
# 86120caa19f5: Waiting
# c0f2d44469de: Waiting
# 638bc09d59ce: Waiting
# cec7eddb8044: Waiting
# 31cda9815495: Waiting
# a1b48f84f0d1: Waiting
# 484f821166bc: Waiting
# 6d70e314b196: Waiting
# f3b4a5f15c7a: Download complete
# 57ffbe87baa1: Verifying Checksum
# 57ffbe87baa1: Download complete
# 01bf7da0a88c: Verifying Checksum
# 01bf7da0a88c: Download complete
# c0f2d44469de: Verifying Checksum
# c0f2d44469de: Download complete
# 638bc09d59ce: Verifying Checksum
# 638bc09d59ce: Download complete
# 31cda9815495: Verifying Checksum
# 31cda9815495: Download complete
# a1b48f84f0d1: Verifying Checksum
# a1b48f84f0d1: Download complete
# 86120caa19f5: Verifying Checksum
# 86120caa19f5: Download complete
# cec7eddb8044: Verifying Checksum
# cec7eddb8044: Download complete
# 6d70e314b196: Verifying Checksum
# 6d70e314b196: Download complete
# 01bf7da0a88c: Pull complete
# f3b4a5f15c7a: Pull complete
# 57ffbe87baa1: Pull complete
# 86120caa19f5: Pull complete
# StepRun( batch-score-diabetes ) Status: Running
# c0f2d44469de: Pull complete
# 638bc09d59ce: Pull complete
# cec7eddb8044: Pull complete
# 31cda9815495: Pull complete
# a1b48f84f0d1: Pull complete
#
# 484f821166bc: Retrying in 5 seconds
# 484f821166bc: Retrying in 4 seconds
# 484f821166bc: Retrying in 3 seconds
# 484f821166bc: Retrying in 2 seconds
# 484f821166bc: Retrying in 1 second
# 484f821166bc: Verifying Checksum
# 484f821166bc: Download complete
# 484f821166bc: Pull complete
# 6d70e314b196: Pull complete
# Digest: sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1@sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
#  ---> 63a0a67d2c72
# Step 2/18 : USER root
#  ---> Running in 6a8156e0b77b
# Removing intermediate container 6a8156e0b77b
#  ---> 0e7577f8567d
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 42db1fdd8a15
# Removing intermediate container 42db1fdd8a15
#  ---> 3728527fca09
# Step 4/18 : WORKDIR /
#  ---> Running in d0bb75dbecbb
# Removing intermediate container d0bb75dbecbb
#  ---> e0152fd79892
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> fc5cda25fbb5
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 0effcc77ff3f
# Removing intermediate container 0effcc77ff3f
#  ---> 7fc3097dd814
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> c36ced673318
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 4495dd706888
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | #          |  11%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# wheel-0.36.2         | 33 KB     |            |   0%
# wheel-0.36.2         | 33 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# setuptools-52.0.0    | 724 KB    |            |   0%
# setuptools-52.0.0    | 724 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# ca-certificates-2021 | 112 KB    |            |   0%
# ca-certificates-2021 | 112 KB    | ########## | 100%
#
# intel-openmp-2021.2. | 1.3 MB    |            |   0%
# intel-openmp-2021.2. | 1.3 MB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 5          |   5%
# mkl-2020.2           | 138.3 MB  | #1         |  11%
# mkl-2020.2           | 138.3 MB  | #7         |  17%
# mkl-2020.2           | 138.3 MB  | ##3        |  24%
# mkl-2020.2           | 138.3 MB  | ###        |  30%
# mkl-2020.2           | 138.3 MB  | ###7       |  37%
# mkl-2020.2           | 138.3 MB  | ####3      |  43%
# mkl-2020.2           | 138.3 MB  | ####9      |  50%
# mkl-2020.2           | 138.3 MB  | #####5     |  56%
# mkl-2020.2           | 138.3 MB  | ######2    |  62%
# mkl-2020.2           | 138.3 MB  | ######9    |  69%
# mkl-2020.2           | 138.3 MB  | #######5   |  76%
# mkl-2020.2           | 138.3 MB  | ########1  |  82%
# mkl-2020.2           | 138.3 MB  | ########8  |  89%
# mkl-2020.2           | 138.3 MB  | #########5 |  95%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ##1        |  21%
# python-3.6.2         | 23.6 MB   | #####4     |  54%
# python-3.6.2         | 23.6 MB   | ########9  |  89%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 17 KB     |            |   0%
# threadpoolctl-2.1.0  | 17 KB     | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# pip-21.1.2           | 1.8 MB    |            |   0%
# pip-21.1.2           | 1.8 MB    | ########## | 100%
# pip-21.1.2           | 1.8 MB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ####1      |  42%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.22o9p3bq.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.30.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core
#   Downloading azureml_core-1.30.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.18.0-py3-none-any.whl (39.4 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.30.0
#   Downloading azureml_dataset_runtime-1.30.0-py3-none-any.whl (3.5 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: six>=1.10 in /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.22o9p3bq.requirements.txt (line 1)) (1.16.0)
# Collecting python-dateutil>=2.5.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: numpy>=1.13.0 in /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.22o9p3bq.requirements.txt (line 1)) (1.19.2)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.22o9p3bq.requirements.txt (line 1)) (52.0.0.post20210125)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.0.0-py2.py3-none-any.whl (663 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.0.0-py2.py3-none-any.whl (312 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.15.0-py2.py3-none-any.whl (138 kB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.16.0a,>=2.15.0a
#   Downloading azureml_dataprep-2.15.1-py3-none-any.whl (39.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-dataprep-rslex<1.14.0a,>=1.13.0dev0
#   Downloading azureml_dataprep_rslex-1.13.0-cp36-cp36m-manylinux2010_x86_64.whl (9.8 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.5.0-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core->-r /azureml-environment-setup/condaenv.22o9p3bq.requirements.txt (line 2)) (2021.5.30)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.17.0-py3-none-any.whl (39.4 MB)
#   Downloading azureml_dataprep-2.16.1-py3-none-any.whl (39.4 MB)
#   Downloading azureml_dataprep-2.16.0-py3-none-any.whl (39.4 MB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=bcfdf441b72d4779617987832f14bd87311f2ea028ab5100fd23e57e3af7de48
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=cf25335b72ea695ca90c11a1397ce76de8bf4b5cf9ce53fad6a152e8bd8af091
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=d14cff2c7d7ff161285aa81244ed58f16890908331e60651e9c007bd03984f25
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, chardet, requests, portalocker, oauthlib, msal, requests-oauthlib, python-dateutil, msal-extensions, isodate, distro, azure-core, zipp, typing-extensions, msrest, dotnetcore2, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, websocket-client, ruamel.yaml.clib, pytz, pyopenssl, pyasn1, pyarrow, msrestazure, MarkupSafe, jeepney, importlib-metadata, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, werkzeug, SecretStorage, ruamel.yaml, pathspec, pandas, ndg-httpsclient, liac-arff, jsonpickle, jmespath, Jinja2, itsdangerous, fusepy, docker, dill, contextlib2, click, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, json-logging-py, gunicorn, flask, configparser, azureml-model-management-sdk, azureml-core, applicationinsights, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.15.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.0.0 azure-mgmt-core-1.2.2 azure-mgmt-keyvault-9.0.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.30.0 azureml-dataprep-2.15.1 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.13.0 azureml-dataset-runtime-1.30.0 azureml-defaults-1.30.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.4 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 idna-2.10 importlib-metadata-4.5.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.12.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.5 websocket-client-1.1.0 werkzeug-1.0.1 zipp-3.4.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 4495dd706888
#  ---> 9465540f2097
# Step 9/18 : ENV PATH /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/bin:$PATH
#  ---> Running in 4f2287d25378
# Removing intermediate container 4f2287d25378
#  ---> 951794f7ca29
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 87e266255ab4
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 874fb4bf4a74
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1
#  ---> Running in 1b6d4aff7c73
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 1b6d4aff7c73
#  ---> 924f6cd2218d
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1
#  ---> Running in 5a6cccb73b50
# Removing intermediate container 5a6cccb73b50
#  ---> 7f4e35ea14f2
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_4811aabb4e938e79d95db3f7ad01efe1/lib:$LD_LIBRARY_PATH
#  ---> Running in 8bde03f74e5b
# Removing intermediate container 8bde03f74e5b
#  ---> 2e7f10705120
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> b1d475b2ef4b
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 6becd9371b68
# Removing intermediate container 6becd9371b68
#  ---> 14ba2c0f4639
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in d014a66ecd15
# Removing intermediate container d014a66ecd15
#  ---> 9b4a31cc0c88
# Step 18/18 : CMD ["bash"]
#  ---> Running in 0938cc60ca99
# Removing intermediate container 0938cc60ca99
#  ---> 6e4968284b75
# Successfully built 6e4968284b75
# Successfully tagged a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8:latest
# Successfully tagged a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8:1
# 2021/06/20 14:07:45 Successfully executed container: acb_step_0
# 2021/06/20 14:07:45 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/20 14:07:45 Pushing image: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8:1, attempt 1
# The push refers to repository [a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8]
# 5b47d6eb45e5: Preparing
# c42db1dae3c9: Preparing
# 41c5158af815: Preparing
# 4496cb79a17c: Preparing
# 95bc5b3d08e6: Preparing
# 3e8dd420421d: Preparing
# 5c3b7afb5315: Preparing
# d67d39ee7bd9: Preparing
# 262e767f7db4: Preparing
# 79dc78335362: Preparing
# cd522a282582: Preparing
# 5ffe0b2ed9b9: Preparing
# edf4c99a758a: Preparing
# 28f3c2496426: Preparing
# 3df6d6ce3c09: Preparing
# 708986b6155f: Preparing
# d4ac134e30e9: Preparing
# 8cafc6d2db45: Preparing
# a5d4bacb0351: Preparing
# 5153e1acaabc: Preparing
# 3e8dd420421d: Waiting
# 5c3b7afb5315: Waiting
# d67d39ee7bd9: Waiting
# 262e767f7db4: Waiting
# 79dc78335362: Waiting
# cd522a282582: Waiting
# 5ffe0b2ed9b9: Waiting
# edf4c99a758a: Waiting
# 28f3c2496426: Waiting
# 3df6d6ce3c09: Waiting
# 708986b6155f: Waiting
# d4ac134e30e9: Waiting
# 8cafc6d2db45: Waiting
# a5d4bacb0351: Waiting
# 5153e1acaabc: Waiting
# 41c5158af815: Pushed
# 4496cb79a17c: Pushed
# 5b47d6eb45e5: Pushed
# c42db1dae3c9: Pushed
# 5c3b7afb5315: Pushed
# 3e8dd420421d: Pushed
# d67d39ee7bd9: Pushed
# 262e767f7db4: Pushed
# 79dc78335362: Pushed
# cd522a282582: Pushed
# edf4c99a758a: Pushed
# 5ffe0b2ed9b9: Pushed
# 3df6d6ce3c09: Pushed
# 708986b6155f: Pushed
# 8cafc6d2db45: Pushed
#
# a5d4bacb0351: Pushed
# 28f3c2496426: Pushed
# 5153e1acaabc: Pushed
# d4ac134e30e9: Pushed
#
# 95bc5b3d08e6: Pushed
# 1: digest: sha256:abfe0166633647e263425d2af2d03a426df9129f38f25e2b4d6a465e78bbf871 size: 4514
# 2021/06/20 14:09:43 Successfully pushed image: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8:1
# 2021/06/20 14:09:43 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/20 14:09:43 Pushing image: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8:latest, attempt 1
# The push refers to repository [a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8]
# 5b47d6eb45e5: Preparing
# c42db1dae3c9: Preparing
# 41c5158af815: Preparing
# 4496cb79a17c: Preparing
# 95bc5b3d08e6: Preparing
# 3e8dd420421d: Preparing
# 5c3b7afb5315: Preparing
# d67d39ee7bd9: Preparing
# 262e767f7db4: Preparing
# 79dc78335362: Preparing
# cd522a282582: Preparing
# 5ffe0b2ed9b9: Preparing
# edf4c99a758a: Preparing
# 28f3c2496426: Preparing
# 3df6d6ce3c09: Preparing
# 708986b6155f: Preparing
# d4ac134e30e9: Preparing
# 8cafc6d2db45: Preparing
# a5d4bacb0351: Preparing
# 5153e1acaabc: Preparing
# 3e8dd420421d: Waiting
# 5c3b7afb5315: Waiting
# d67d39ee7bd9: Waiting
# 262e767f7db4: Waiting
# 79dc78335362: Waiting
# cd522a282582: Waiting
# 5ffe0b2ed9b9: Waiting
# edf4c99a758a: Waiting
# 28f3c2496426: Waiting
# 3df6d6ce3c09: Waiting
# 708986b6155f: Waiting
# d4ac134e30e9: Waiting
# 8cafc6d2db45: Waiting
# a5d4bacb0351: Waiting
# 5153e1acaabc: Waiting
# 95bc5b3d08e6: Layer already exists
# 41c5158af815: Layer already exists
# c42db1dae3c9: Layer already exists
# 5b47d6eb45e5: Layer already exists
# 4496cb79a17c: Layer already exists
# 3e8dd420421d: Layer already exists
# 5c3b7afb5315: Layer already exists
# d67d39ee7bd9: Layer already exists
# 262e767f7db4: Layer already exists
# 79dc78335362: Layer already exists
# edf4c99a758a: Layer already exists
# 3df6d6ce3c09: Layer already exists
# cd522a282582: Layer already exists
# 5ffe0b2ed9b9: Layer already exists
# 28f3c2496426: Layer already exists
# d4ac134e30e9: Layer already exists
# 708986b6155f: Layer already exists
# 8cafc6d2db45: Layer already exists
# 5153e1acaabc: Layer already exists
# a5d4bacb0351: Layer already exists
# latest: digest: sha256:abfe0166633647e263425d2af2d03a426df9129f38f25e2b4d6a465e78bbf871 size: 4514
# 2021/06/20 14:09:44 Successfully pushed image: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io/azureml/azureml_ebe3b677f35326a152d32e2af83e59f8:latest
# 2021/06/20 14:09:44 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 220.752994)
# 2021/06/20 14:09:44 Populating digests for step ID: acb_step_0...
# 2021/06/20 14:09:48 Successfully populated digests for step ID: acb_step_0
# 2021/06/20 14:09:48 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 117.766566)
# 2021/06/20 14:09:48 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.667572)
# 2021/06/20 14:09:48 The following dependencies were found:
# 2021/06/20 14:09:48
# - image:
#     registry: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io
#     repository: azureml/azureml_ebe3b677f35326a152d32e2af83e59f8
#     tag: latest
#     digest: sha256:abfe0166633647e263425d2af2d03a426df9129f38f25e2b4d6a465e78bbf871
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210513.v1
#     digest: sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
#   git: {}
# - image:
#     registry: a72b0ccaf6be498c960c3ed99d06bf50.azurecr.io
#     repository: azureml/azureml_ebe3b677f35326a152d32e2af83e59f8
#     tag: "1"
#     digest: sha256:abfe0166633647e263425d2af2d03a426df9129f38f25e2b4d6a465e78bbf871
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210513.v1
#     digest: sha256:70b87b000d8a867480781b6e5bd582037a7fc8b6dcb09f4d0f36762a237ee897
#   git: {}
#
# Run ID: ca2 was successful after 5m49s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_dbdaad318607a280f3a3ec7c1d5681ba128a8d593b574bd758774493393491fc_d.txt
# ========================================================================================================================
# 2021-06-20T14:14:41Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24767 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-06-20T14:14:42Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore
# 2021-06-20T14:14:42Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-06-20T14:14:42Z Starting output-watcher...
# 2021-06-20T14:14:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-06-20T14:14:43Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2021-06-20T14:14:43Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-06-20T14:14:43Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b17bb515790c315eb1f89b65065d0364b10cffbaeeac94dedde8fd6310b0b542_d.txt
# ========================================================================================================================
# 2021-06-20T14:14:42Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24791 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-06-20T14:14:42Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore
# 2021-06-20T14:14:43Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-06-20T14:14:43Z Starting output-watcher...
# 2021-06-20T14:14:43Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_fe4afc798de401edfb76dc27a38b1703
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 9e11d437728f: Pulling fs layer
# 3506c910620f: Pulling fs layer
# afe6352c52c2: Pulling fs layer
# 45d886309004: Pulling fs layer
# 2ce19e789040: Pulling fs layer
# f2a2950e1ed4: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 9e11d437728f: Waiting
# 3506c910620f: Waiting
# afe6352c52c2: Waiting
# 45d886309004: Waiting
# 2ce19e789040: Waiting
# f2a2950e1ed4: Waiting
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 9e11d437728f: Verifying Checksum
# 9e11d437728f: Download complete
# afe6352c52c2: Verifying Checksum
# afe6352c52c2: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 45d886309004: Verifying Checksum
# 45d886309004: Download complete
# f2a2950e1ed4: Verifying Checksum
# f2a2950e1ed4: Download complete
# 2ce19e789040: Verifying Checksum
# 2ce19e789040: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# 3506c910620f: Verifying Checksum
# 3506c910620f: Download complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 9e11d437728f: Pull complete
# 3506c910620f: Pull complete
# afe6352c52c2: Pull complete
# 45d886309004: Pull complete
# 2ce19e789040: Pull complete
# f2a2950e1ed4: Pull complete
# Digest: sha256:5224cd9c4e07c9304c90193ab084da3cf8643e81065eef4d81c2c4029c58248c
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_fe4afc798de401edfb76dc27a38b1703:latest
# viennaglobal.azurecr.io/azureml/azureml_fe4afc798de401edfb76dc27a38b1703:latest
# 2021-06-20T14:15:06Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-06-20T14:15:06Z Check if container 4fd847a9-e79f-48a2-b79a-a87813473cfc_DataSidecar already exist exited with 0,
#
# c14cd5378fba966d0e025f5e33450d8f21d8aeef182a62cda188c98a67ed24b6
# 2021-06-20T14:15:10Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-06-20T14:15:10Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-a08621e79ef625230ae2884e779bf048-081bc12c0b814018-01 -sshRequired=false]
# 2021/06/20 14:15:10 Starting App Insight Logger for task:  containerSetup
# 2021/06/20 14:15:10 Version: 3.0.01622.0001 Branch: .SourceBranch Commit: 1141612
# 2021/06/20 14:15:10 Entered ContainerSetupTask - Preparing infiniband
# 2021/06/20 14:15:10 Starting infiniband setup
# 2021/06/20 14:15:10 Python Version found is Python 3.7.9
#
# 2021/06/20 14:15:10 Returning Python Version as 3.7
# 2021/06/20 14:15:10 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/06/20 14:15:10 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-06-20T14:15:10Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/06/20 14:15:10 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/06/20 14:15:10 Not setting up Infiniband in Container
# 2021/06/20 14:15:10 Not setting up Infiniband in Container
# 2021-06-20T14:15:10Z Not setting up Infiniband in Container
# 2021/06/20 14:15:10 Python Version found is Python 3.7.9
#
# 2021/06/20 14:15:10 Returning Python Version as 3.7
# 2021/06/20 14:15:10 sshd inside container not required for job, skipping setup.
# 2021/06/20 14:15:11 All App Insights Logs was send successfully
# 2021/06/20 14:15:11 App Insight Client has already been closed
# 2021/06/20 14:15:11 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-06-20T14:15:11Z Starting docker container succeeded.
# 2021-06-20T14:15:11Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/65_job_prep-tvmps_b17bb515790c315eb1f89b65065d0364b10cffbaeeac94dedde8fd6310b0b542_d.txt
# ===============================================================================================================
# [2021-06-20T14:15:13.629382] Entering job preparation.
# [2021-06-20T14:15:14.586469] Starting job preparation.
# [2021-06-20T14:15:14.586525] Extracting the control code.
# [2021-06-20T14:15:14.587214] Starting extract_project.
# [2021-06-20T14:15:14.587252] Starting to extract zip file.
# [2021-06-20T14:15:14.606588] Finished extracting zip file.
# [2021-06-20T14:15:14.609295] Using urllib.request Python 3.0 or later
# [2021-06-20T14:15:14.609403] Start fetching snapshots.
# [2021-06-20T14:15:14.609437] Start fetching snapshot.
# [2021-06-20T14:15:14.609446] Retrieving project from snapshot: 0badd957-ae6b-441e-bb3c-b6495ad443e3
# Starting the daemon thread to refresh tokens in background for process with pid = 54
# [2021-06-20T14:15:14.903506] Finished fetching snapshot.
# [2021-06-20T14:15:14.903540] Start fetching snapshot.
# [2021-06-20T14:15:14.903752] Retrieving project from snapshot: cad07dbe-dac9-44ed-a688-fce05f3dcc85
# [2021-06-20T14:15:22.562903] Finished fetching snapshot.
# [2021-06-20T14:15:22.562938] Finished fetching snapshots.
# [2021-06-20T14:15:22.562952] Finished extract_project.
# [2021-06-20T14:15:22.564116] Finished fetching and extracting the control code.
# [2021-06-20T14:15:22.570842] Start run_history_prep.
# [2021-06-20T14:15:22.577575] Job preparation is complete.
# [2021-06-20T14:15:22.577828] Entering Data Context Managers in Sidecar
# [2021-06-20T14:15:22.578647] Running Sidecar prep cmd...
# [2021-06-20T14:15:22.947994] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc
# [2021-06-20T14:15:22.950037] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.28.0 azureml-dataprep==2.16.0. Session id: e43f7d80-5ed1-4a6c-84e9-37cc8413a4f8. Run id: 4fd847a9-e79f-48a2-b79a-a87813473cfc.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "98ea1adb-cbd4-4630-b12a-0ebfb020362f",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='aml-workspace', subscription_id='7bcf0e2e-9911-4b19-a0db-99354664b6f1', resource_group='aml-resources')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f
# Acquired lockfile /tmp/4fd847a9-e79f-48a2-b79a-a87813473cfc-datastore.lock to downloading input data references
# [2021-06-20T14:15:32.606660] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-06-20T14:15:32.799750] Ran Sidecar prep cmd.
# [2021-06-20T14:15:32.800266] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/06/20 14:16:13 Starting App Insight Logger for task:  runTaskLet
# 2021/06/20 14:16:13 Version: 3.0.01622.0001 Branch: .SourceBranch Commit: 1141612
# 2021/06/20 14:16:13 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/06/20 14:16:13 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-06-20T14:16:13.477411] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2021-06-20T14:16:13.948959] Entering Run History Context Manager.
# [2021-06-20T14:16:14.613073] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc
# [2021-06-20T14:16:14.613297] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-06-20T14:16:14.613323] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/mounts/workspaceblobstore/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/inferences', '--input_fds_0', 'diabetes_batch']
#
# 2021/06/20 14:16:18 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_dbdaad318607a280f3a3ec7c1d5681ba128a8d593b574bd758774493393491fc_d.txt
# ===============================================================================================================
# [2021-06-20T14:16:54.614242] Entering job release
# [2021-06-20T14:16:55.415660] Starting job release
# [2021-06-20T14:16:55.416132] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 279
# [2021-06-20T14:16:55.416552] job release stage : upload_datastore starting...
# [2021-06-20T14:16:55.428844] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-06-20T14:16:55.429081] job release stage : execute_job_release starting...
# [2021-06-20T14:16:55.429601] Entering context manager injector.
# [2021-06-20T14:16:55.430115] job release stage : copy_batchai_cached_logs starting...
# [2021-06-20T14:16:55.430187] job release stage : copy_batchai_cached_logs completed...
# [2021-06-20T14:16:55.442063] job release stage : upload_datastore completed...
# [2021-06-20T14:16:55.533839] job release stage : send_run_telemetry starting...
# [2021-06-20T14:16:55.545303] get vm size and vm region successfully.
# [2021-06-20T14:16:55.554062] job release stage : execute_job_release completed...
# [2021-06-20T14:16:55.560996] get compute meta data successfully.
# [2021-06-20T14:16:55.853725] post artifact meta request successfully.
# [2021-06-20T14:16:55.915474] upload compute record artifact successfully.
# [2021-06-20T14:16:55.915642] job release stage : send_run_telemetry completed...
# [2021-06-20T14:16:55.916198] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-06-20T14:16:55.916509] Running Sidecar release cmd...
# [2021-06-20T14:16:55.993983] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f.
# Exit __exit__ of DatasetContextManager
# [2021-06-20T14:16:56.031335] Removing absolute paths from host...
# [2021-06-20T14:16:56.031544] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-06-20T14:16:56.580184] Ran Sidecar release cmd.
# [2021-06-20T14:16:56.580400] Job release is complete
#
# Streaming azureml-logs/75_job_post-tvmps_b17bb515790c315eb1f89b65065d0364b10cffbaeeac94dedde8fd6310b0b542_d.txt
# ===============================================================================================================
# [2021-06-20T14:16:55.238385] Entering job release
# [2021-06-20T14:16:56.038060] job release stage : copy_batchai_cached_logs starting...
# [2021-06-20T14:16:56.038100] job release stage : copy_batchai_cached_logs completed...
# [2021-06-20T14:16:56.038351] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-06-20T14:16:56.038920] Running Sidecar release cmd...
# [2021-06-20T14:16:56.080033] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-workspace/azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/wd/diabetes_batch_98ea1adb-cbd4-4630-b12a-0ebfb020362f.
# Exit __exit__ of DatasetContextManager
# [2021-06-20T14:16:56.114541] Removing absolute paths from host...
# [2021-06-20T14:16:56.114777] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-06-20T14:16:56.793050] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '4fd847a9-e79f-48a2-b79a-a87813473cfc', 'target': 'compu2', 'status': 'Completed', 'startTimeUtc': '2021-06-20T14:14:37.024434Z', 'endTimeUtc': '2021-06-20T14:17:18.910112Z', 'properties': {'ContentSnapshotId': '0badd957-ae6b-441e-bb3c-b6495ad443e3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '852ed78e-8c36-4a28-9a52-f715117f1124', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '77a68c4a', 'azureml.pipelinerunid': '39179b6d-e8c9-49b3-be5e-6c7afb2ed872', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '98ea1adb-cbd4-4630-b12a-0ebfb020362f'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.30.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'compu2', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/4fd847a9-e79f-48a2-b79a-a87813473cfc/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '98ea1adb-cbd4-4630-b12a-0ebfb020362f', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2021-06-20T14:03:56Z_618d7f92', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults', 'azureml-core', 'azureml-dataprep[fuse]']}], 'name': 'azureml_4811aabb4e938e79d95db3f7ad01efe1'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '39179b6d-e8c9-49b3-be5e-6c7afb2ed872', 'status': 'Completed', 'startTimeUtc': '2021-06-20T14:02:47.225158Z', 'endTimeUtc': '2021-06-20T14:17:21.368229Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlworksstorage1433a447c.blob.core.windows.net/azureml/ExperimentRun/dcid.39179b6d-e8c9-49b3-be5e-6c7afb2ed872/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=%2BMKVrWTFKvYWu3%2Fl4rNmB4yibOKo8UJa7T6MO6JdBGs%3D&st=2021-06-20T14%3A07%3A22Z&se=2021-06-20T22%3A17%3A22Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlworksstorage1433a447c.blob.core.windows.net/azureml/ExperimentRun/dcid.39179b6d-e8c9-49b3-be5e-6c7afb2ed872/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=JE%2F9wcMS2r5uadc7kfcEQW8c4CTTQB5ouH69rq73gas%3D&st=2021-06-20T14%3A07%3A23Z&se=2021-06-20T22%3A17%3A23Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlworksstorage1433a447c.blob.core.windows.net/azureml/ExperimentRun/dcid.39179b6d-e8c9-49b3-be5e-6c7afb2ed872/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=9KEgUuuXDFppieeodMbYg%2BrMp5avCcP9zH9OqNeorQ8%3D&st=2021-06-20T14%3A07%3A23Z&se=2021-06-20T22%3A17%3A23Z&sp=r'}, 'submittedBy': 'franmarq@hotmail.com MÁRQUEZ'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   31.csv           0
# 1   32.csv           0
# 2   33.csv           0
# 3   34.csv           0
# 4   35.csv           0
# 5   18.csv           0
# 6   19.csv           0
# 7    2.csv           0
# 8   20.csv           0
# 9   21.csv           0
# 10  13.csv           1
# 11  14.csv           0
# 12  15.csv           0
# 13  16.csv           1
# 14  17.csv           0
# 15   5.csv           0
# 16  50.csv           0
# 17  51.csv           1
# 18  52.csv           0
# 19  53.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 29e007f0-d62f-442e-b5b0-e284076e3156,
# Status: Active,
# Endpoint: https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/7bcf0e2e-9911-4b19-a0db-99354664b6f1/resourceGroups/aml-resources/providers/Microsoft.MachineLearningServices/workspaces/aml-workspace/PipelineRuns/PipelineSubmit/29e007f0-d62f-442e-b5b0-e284076e3156)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/7bcf0e2e-9911-4b19-a0db-99354664b6f1/resourceGroups/aml-resources/providers/Microsoft.MachineLearningServices/workspaces/aml-workspace/PipelineRuns/PipelineSubmit/29e007f0-d62f-442e-b5b0-e284076e3156

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '4de88c50-c51b-4a29-972d-173e93cd27d4'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 4de88c50-c51b-4a29-972d-173e93cd27d4
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/4de88c50-c51b-4a29-972d-173e93cd27d4?wsid=/subscriptions/7bcf0e2e-9911-4b19-a0db-99354664b6f1/resourcegroups/aml-resources/workspaces/aml-workspace&tid=935b4e79-1fd0-49cd-ae65-f81a2054edd6
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '4de88c50-c51b-4a29-972d-173e93cd27d4', 'status': 'Completed', 'startTimeUtc': '2021-06-20T14:21:11.874431Z', 'endTimeUtc': '2021-06-20T14:21:14.458395Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': '29e007f0-d62f-442e-b5b0-e284076e3156'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlworksstorage1433a447c.blob.core.windows.net/azureml/ExperimentRun/dcid.4de88c50-c51b-4a29-972d-173e93cd27d4/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=BTWxT9jRcBuWLjODFusg8OjD9oqMZed7EiwisRqDJX4%3D&st=2021-06-20T14%3A11%3A24Z&se=2021-06-20T22%3A21%3A24Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlworksstorage1433a447c.blob.core.windows.net/azureml/ExperimentRun/dcid.4de88c50-c51b-4a29-972d-173e93cd27d4/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=hpL%2BcEvnA%2FtdWLAQVFfpnRNK54VZZhUyDQ0awE3T%2Fdw%3D&st=2021-06-20T14%3A11%3A24Z&se=2021-06-20T22%3A21%3A24Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlworksstorage1433a447c.blob.core.windows.net/azureml/ExperimentRun/dcid.4de88c50-c51b-4a29-972d-173e93cd27d4/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=O8rzSbq0cP4BA3HxQ8Xrq%2FcbKMRgfTHgSv9HPfvii%2F4%3D&st=2021-06-20T14%3A11%3A24Z&se=2021-06-20T22%3A21%3A24Z&sp=r'}, 'submittedBy': 'franmarq@hotmail.com MÁRQUEZ'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   31.csv           0
# 1   32.csv           0
# 2   33.csv           0
# 3   34.csv           0
# 4   35.csv           0
# 5   18.csv           0
# 6   19.csv           0
# 7    2.csv           0
# 8   20.csv           0
# 9   21.csv           0
# 10  13.csv           1
# 11  14.csv           0
# 12  15.csv           0
# 13  16.csv           1
# 14  17.csv           0
# 15   5.csv           0
# 16  50.csv           0
# 17  51.csv           1
# 18  52.csv           0
# 19  53.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
